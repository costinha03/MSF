# %%
import numpy as np
import matplotlib.pyplot as mp

mp.arrow(0,0,3,4,width=0.1)
mp.arrow(0,0,4,-3,width = 0.1)
mp.axis("equal")
# Out:
# (-0.26000000000000006, 4.58, -3.6515, 4.7415)

# %%
#4 F*cos(60) = 2

import numpy as np
Fx = 2
Fv = 2/np.cos(np.deg2rad(60))
Fy = Fv * np.sen(np.deg2rad(60))



print(F)
# Out:
# 3.999999999999999
